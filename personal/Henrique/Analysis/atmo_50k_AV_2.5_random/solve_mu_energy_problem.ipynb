# %%
import uproot
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mplhep
from scipy.stats import norm
from scipy.optimize import curve_fit
import matplotlib.mlab as mlab
import time
from matplotlib.colors import LogNorm
mplhep.style.use(mplhep.style.ROOT)
from pprint import pprint
import polars as pl

from tqdm import tqdm
from functools import partialmethod
tqdm.__init__ = partialmethod(tqdm.__init__, disable=False)

from dataclasses import dataclass

plt.rcParams.update({'font.size': 16,
                     'grid.linestyle': '--',
                     'axes.grid': True,
                     'figure.autolayout': True
                     })

# %%
# with uproot.open('/home/pgranger/atmospherics/sum_50k_hd_AV.root') as f:
file = '/home/henrique/Documents/Atmos_Pandora/data/atm_50k_hd_AV_2.5_random/flatcaf_sum.root'
def loadData(file):
    with uproot.open(file) as f:
        tree = f['cafTree']
        tree.show()
        cols = [key for key in tree.keys() if "Jagged" not in str(tree[key].interpretation)]

        data = f['cafTree'].arrays(cols, library='np')
        df = pl.from_pandas(pd.DataFrame(data))
        return df
    # print(df)

df = loadData(file)
dfold = loadData('/home/henrique/Documents/Atmos_Pandora/data/atm_50k_hd_AV/caf_sum.root')
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# rec.CVNResult0Neu... | float                    | AsDtype('>f4')
# rec.CVNResult0Pions  | float                    | AsDtype('>f4')
# rec.CVNResult0Piz... | float                    | AsDtype('>f4')
# rec.CVNResult0Pro... | float                    | AsDtype('>f4')
# rec.CVNResult1Neu... | float                    | AsDtype('>f4')
# rec.CVNResult1Pions  | float                    | AsDtype('>f4')
# rec.CVNResult1Piz... | float                    | AsDtype('>f4')
# rec.CVNResult1Pro... | float                    | AsDtype('>f4')
# rec.CVNResult2Neu... | float                    | AsDtype('>f4')
# rec.CVNResult2Pions  | float                    | AsDtype('>f4')
# rec.CVNResult2Piz... | float                    | AsDtype('>f4')
# rec.CVNResult2Pro... | float                    | AsDtype('>f4')
# rec.CVNResultIsAn... | float                    | AsDtype('>f4')
# rec.CVNResultNC      | float                    | AsDtype('>f4')
# rec.CVNResultNNeu... | float                    | AsDtype('>f4')
# rec.CVNResultNPions  | float                    | AsDtype('>f4')
# rec.CVNResultNPiz... | float                    | AsDtype('>f4')
# rec.CVNResultNPro... | float                    | AsDtype('>f4')
# rec.CVNResultNue     | float                    | AsDtype('>f4')
# rec.CVNResultNumu    | float                    | AsDtype('>f4')
# rec.CVNResultNutau   | float                    | AsDtype('>f4')
# rec.EVisReco_ND      | double                   | AsDtype('>f8')
# rec.EVisReco_nue     | double                   | AsDtype('>f8')
# rec.EVisReco_numu    | double                   | AsDtype('>f8')
# rec.Ehad_veto        | float                    | AsDtype('>f4')
# rec.Elep             | float                    | AsDtype('>f4')
# rec.Elep_reco        | float                    | AsDtype('>f4')
# rec.Ev               | float                    | AsDtype('>f4')
# rec.Ev_reco          | float                    | AsDtype('>f4')
# rec.Ev_reco_nue      | float                    | AsDtype('>f4')
# rec.Ev_reco_numu     | float                    | AsDtype('>f4')
# rec.GENIE_Scatter... | int32_t                  | AsDtype('>i4')
# rec.HadE             | double                   | AsDtype('>f8')
# rec.HadEVisReco_FD   | double                   | AsDtype('>f8')
# rec.HadEVisReco_ND   | double                   | AsDtype('>f8')
# rec.LepE             | float                    | AsDtype('>f4')
# rec.LepEndpoint.x    | float                    | AsDtype('>f4')
# rec.LepEndpoint.y    | float                    | AsDtype('>f4')
# rec.LepEndpoint.z    | float                    | AsDtype('>f4')
# rec.LepMomX          | float                    | AsDtype('>f4')
# rec.LepMomY          | float                    | AsDtype('>f4')
# rec.LepMomZ          | float                    | AsDtype('>f4')
# rec.LepNuAngle       | float                    | AsDtype('>f4')
# rec.LepPDG           | int32_t                  | AsDtype('>i4')
# rec.LongestTrackC... | int32_t                  | AsDtype('>i4')
# rec.NDMassCorrWeight | double                   | AsDtype('>f8')
# rec.NuMomX           | float                    | AsDtype('>f4')
# rec.NuMomY           | float                    | AsDtype('>f4')
# rec.NuMomZ           | float                    | AsDtype('>f4')
# rec.OffAxisFluxBin   | int32_t                  | AsDtype('>i4')
# rec.OffAxisFluxCo... | int32_t                  | AsDtype('>i4')
# rec.ProxyRecoLepE    | double                   | AsDtype('>f8')
# rec.Q2               | float                    | AsDtype('>f4')
# rec.RecoHadEnNue     | float                    | AsDtype('>f4')
# rec.RecoHadEnNumu    | float                    | AsDtype('>f4')
# rec.RecoLepEnNue     | float                    | AsDtype('>f4')
# rec.RecoLepEnNumu    | float                    | AsDtype('>f4')
# rec.RecoMethodNue    | int32_t                  | AsDtype('>i4')
# rec.RecoMethodNumu   | int32_t                  | AsDtype('>i4')
# rec.RegCNNNueE       | float                    | AsDtype('>f4')
# rec.SpecialHCRunId   | int32_t                  | AsDtype('>i4')
# rec.SpecialRunWeight | double                   | AsDtype('>f8')
# rec.TrackMomMetho... | int32_t                  | AsDtype('>i4')
# rec.VisTrue_NDFD     | double                   | AsDtype('>f8')
# rec.W                | float                    | AsDtype('>f4')
# rec.X                | float                    | AsDtype('>f4')
# rec.Y                | float                    | AsDtype('>f4')
# rec.abspos_x         | double                   | AsDtype('>f8')
# rec.cvnnc            | float                    | AsDtype('>f4')
# rec.cvnnue           | float                    | AsDtype('>f4')
# rec.cvnnumu          | float                    | AsDtype('>f4')
# rec.cvnnutau         | float                    | AsDtype('>f4')
# rec.cvwgt..length    | int32_t                  | AsDtype('>i4')
# rec.cvwgt            | float[]                  | AsJagged(AsDtype('>f4'))
# rec.det_x            | float                    | AsDtype('>f4')
# rec.eDepN            | float                    | AsDtype('>f4')
# rec.eDepOther        | float                    | AsDtype('>f4')
# rec.eDepP            | float                    | AsDtype('>f4')
# rec.eDepPi0          | float                    | AsDtype('>f4')
# rec.eDepPim          | float                    | AsDtype('>f4')
# rec.eDepPip          | float                    | AsDtype('>f4')
# rec.eN               | float                    | AsDtype('>f4')
# rec.eOther           | float                    | AsDtype('>f4')
# rec.eP               | float                    | AsDtype('>f4')
# rec.ePi0             | float                    | AsDtype('>f4')
# rec.ePim             | float                    | AsDtype('>f4')
# rec.ePip             | float                    | AsDtype('>f4')
# rec.ePipm            | double                   | AsDtype('>f8')
# rec.eRecProxy        | double                   | AsDtype('>f8')
# rec.eRec_FromDep     | float                    | AsDtype('>f4')
# rec.eRecoN           | float                    | AsDtype('>f4')
# rec.eRecoOther       | float                    | AsDtype('>f4')
# rec.eRecoP           | float                    | AsDtype('>f4')
# rec.eRecoPi0         | float                    | AsDtype('>f4')
# rec.eRecoPim         | float                    | AsDtype('>f4')
# rec.eRecoPip         | float                    | AsDtype('>f4')
# rec.eTotalPi0        | double                   | AsDtype('>f8')
# rec.event            | int32_t                  | AsDtype('>i4')
# rec.isCC             | int32_t                  | AsDtype('>i4')
# rec.isFD             | int32_t                  | AsDtype('>i4')
# rec.isFHC            | int32_t                  | AsDtype('>i4')
# rec.meta_run         | int32_t                  | AsDtype('>i4')
# rec.meta_subrun      | int32_t                  | AsDtype('>i4')
# rec.mode             | int32_t                  | AsDtype('>i4')
# rec.muon_contained   | int32_t                  | AsDtype('>i4')
# rec.muon_ecal        | int32_t                  | AsDtype('>i4')
# rec.muon_exit        | int32_t                  | AsDtype('>i4')
# rec.muon_tracker     | int32_t                  | AsDtype('>i4')
# rec.mvanue           | float                    | AsDtype('>f4')
# rec.mvanumu          | float                    | AsDtype('>f4')
# rec.mvaresult        | float                    | AsDtype('>f4')
# rec.nN               | int32_t                  | AsDtype('>i4')
# rec.nNucleus         | int32_t                  | AsDtype('>i4')
# rec.nP               | int32_t                  | AsDtype('>i4')
# rec.nUNKNOWN         | int32_t                  | AsDtype('>i4')
# rec.nd.LArID         | uint64_t                 | AsDtype('>u8')
# rec.nd.Residual      | float                    | AsDtype('>f4')
# rec.nd.TMSID         | uint64_t                 | AsDtype('>u8')
# rec.nd.cosTheta      | float                    | AsDtype('>f4')
# rec.nd.gar.cluste... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.cluste... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.cluste... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.cluste... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.cluste... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.cluste... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.cluste... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.cluste... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.cluste... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.cluste... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.cluste... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.cluste... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.cluste... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.cluste... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.cluste... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.cluste... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.cluste... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.cluste... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.cluste... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.cluste... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.cluste... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.cluste... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.cluste... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.gastpc... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.gastpc... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.nFSP      | int32_t                  | AsDtype('>i4')
# rec.nd.gar.nclusters | uint64_t                 | AsDtype('>u8')
# rec.nd.gar.ntracks   | uint64_t                 | AsDtype('>u8')
# rec.nd.gar.partEv... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.partEv... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.pdg..l... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.pdg       | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.ptrue.... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.ptrue     | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.tracks.E  | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.tracks... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.tracks... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.tracks... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.tracks... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.trkLen... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.trkLen    | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.trkLen... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.trkLen... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.nshowers  | uint64_t                 | AsDtype('>u8')
# rec.nd.lar.ntracks   | uint64_t                 | AsDtype('>u8')
# rec.nd.lar.shower... | int32_t                  | AsDtype('>i4')
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.lar.tracks... | int32_t                  | AsDtype('>i4')
# rec.nd.lar.tracks.E  | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.ntrkmatch     | uint64_t                 | AsDtype('>u8')
# rec.nd.tms.ntracks   | uint64_t                 | AsDtype('>u8')
# rec.nd.tms.tracks... | int32_t                  | AsDtype('>i4')
# rec.nd.tms.tracks.E  | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.trkmatch..... | int32_t                  | AsDtype('>i4')
# rec.nd.trkmatch.a... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.trkmatch.l... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.trkmatch.t... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.trkmatch.t... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.niem             | int32_t                  | AsDtype('>i4')
# rec.nik0             | int32_t                  | AsDtype('>i4')
# rec.nikm             | int32_t                  | AsDtype('>i4')
# rec.nikp             | int32_t                  | AsDtype('>i4')
# rec.niother          | int32_t                  | AsDtype('>i4')
# rec.nipi0            | int32_t                  | AsDtype('>i4')
# rec.nipim            | int32_t                  | AsDtype('>i4')
# rec.nipip            | int32_t                  | AsDtype('>i4')
# rec.nuPDG            | int32_t                  | AsDtype('>i4')
# rec.nuPDGunosc       | int32_t                  | AsDtype('>i4')
# rec.nue_pid          | float                    | AsDtype('>f4')
# rec.numu_pid         | float                    | AsDtype('>f4')
# rec.nwgt_CrazyFlux   | int32_t                  | AsDtype('>i4')
# rec.perPOTWeight     | double                   | AsDtype('>f8')
# rec.pileup_energy    | double                   | AsDtype('>f8')
# rec.pot              | double                   | AsDtype('>f8')
# rec.reco_lepton_pdg  | int32_t                  | AsDtype('>i4')
# rec.reco_nc          | int32_t                  | AsDtype('>i4')
# rec.reco_nue         | int32_t                  | AsDtype('>i4')
# rec.reco_numu        | int32_t                  | AsDtype('>i4')
# rec.reco_q           | int32_t                  | AsDtype('>i4')
# rec.run              | int32_t                  | AsDtype('>i4')
# rec.sigma_Elep_reco  | float                    | AsDtype('>f4')
# rec.sigma_Ev_reco    | float                    | AsDtype('>f4')
# rec.sigma_nue_pid    | float                    | AsDtype('>f4')
# rec.sigma_numu_pid   | float                    | AsDtype('>f4')
# rec.subrun           | int32_t                  | AsDtype('>i4')
# rec.theta_reco       | float                    | AsDtype('>f4')
# rec.total_xsSyst_... | float                    | AsDtype('>f4')
# rec.vtx_x            | float                    | AsDtype('>f4')
# rec.vtx_y            | float                    | AsDtype('>f4')
# rec.vtx_z            | float                    | AsDtype('>f4')
# rec.wgt_CrazyFlux... | int32_t                  | AsDtype('>i4')
# rec.wgt_CrazyFlux    | float[]                  | AsJagged(AsDtype('>f4'))
# rec.xsSyst_wgt..l... | int32_t                  | AsDtype('>i4')
# rec.xsSyst_wgt.el... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.xsSyst_wgt.el... | int32_t                  | AsDtype('>i4')
# rec.xsSyst_wgt.elems | float[]                  | AsJagged(AsDtype('>f4'))
# rec.xsSyst_wgt.el... | int32_t[]                | AsJagged(AsDtype('>i4'))
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# rec.CVNResult0Neu... | float                    | AsDtype('>f4')
# rec.CVNResult0Pions  | float                    | AsDtype('>f4')
# rec.CVNResult0Piz... | float                    | AsDtype('>f4')
# rec.CVNResult0Pro... | float                    | AsDtype('>f4')
# rec.CVNResult1Neu... | float                    | AsDtype('>f4')
# rec.CVNResult1Pions  | float                    | AsDtype('>f4')
# rec.CVNResult1Piz... | float                    | AsDtype('>f4')
# rec.CVNResult1Pro... | float                    | AsDtype('>f4')
# rec.CVNResult2Neu... | float                    | AsDtype('>f4')
# rec.CVNResult2Pions  | float                    | AsDtype('>f4')
# rec.CVNResult2Piz... | float                    | AsDtype('>f4')
# rec.CVNResult2Pro... | float                    | AsDtype('>f4')
# rec.CVNResultIsAn... | float                    | AsDtype('>f4')
# rec.CVNResultNC      | float                    | AsDtype('>f4')
# rec.CVNResultNNeu... | float                    | AsDtype('>f4')
# rec.CVNResultNPions  | float                    | AsDtype('>f4')
# rec.CVNResultNPiz... | float                    | AsDtype('>f4')
# rec.CVNResultNPro... | float                    | AsDtype('>f4')
# rec.CVNResultNue     | float                    | AsDtype('>f4')
# rec.CVNResultNumu    | float                    | AsDtype('>f4')
# rec.CVNResultNutau   | float                    | AsDtype('>f4')
# rec.EVisReco_ND      | double                   | AsDtype('>f8')
# rec.EVisReco_nue     | double                   | AsDtype('>f8')
# rec.EVisReco_numu    | double                   | AsDtype('>f8')
# rec.Ehad_veto        | float                    | AsDtype('>f4')
# rec.Elep             | float                    | AsDtype('>f4')
# rec.Elep_reco        | float                    | AsDtype('>f4')
# rec.Ev               | float                    | AsDtype('>f4')
# rec.Ev_reco          | float                    | AsDtype('>f4')
# rec.Ev_reco_nue      | float                    | AsDtype('>f4')
# rec.Ev_reco_numu     | float                    | AsDtype('>f4')
# rec.GENIE_Scatter... | int32_t                  | AsDtype('>i4')
# rec.HadE             | double                   | AsDtype('>f8')
# rec.HadEVisReco_FD   | double                   | AsDtype('>f8')
# rec.HadEVisReco_ND   | double                   | AsDtype('>f8')
# rec.LepE             | float                    | AsDtype('>f4')
# rec.LepEndpoint.x    | float                    | AsDtype('>f4')
# rec.LepEndpoint.y    | float                    | AsDtype('>f4')
# rec.LepEndpoint.z    | float                    | AsDtype('>f4')
# rec.LepMomX          | float                    | AsDtype('>f4')
# rec.LepMomY          | float                    | AsDtype('>f4')
# rec.LepMomZ          | float                    | AsDtype('>f4')
# rec.LepNuAngle       | float                    | AsDtype('>f4')
# rec.LepPDG           | int32_t                  | AsDtype('>i4')
# rec.LongestTrackC... | int32_t                  | AsDtype('>i4')
# rec.NDMassCorrWeight | double                   | AsDtype('>f8')
# rec.NuMomX           | float                    | AsDtype('>f4')
# rec.NuMomY           | float                    | AsDtype('>f4')
# rec.NuMomZ           | float                    | AsDtype('>f4')
# rec.OffAxisFluxBin   | int32_t                  | AsDtype('>i4')
# rec.OffAxisFluxCo... | int32_t                  | AsDtype('>i4')
# rec.ProxyRecoLepE    | double                   | AsDtype('>f8')
# rec.Q2               | float                    | AsDtype('>f4')
# rec.RecoHadEnNue     | float                    | AsDtype('>f4')
# rec.RecoHadEnNumu    | float                    | AsDtype('>f4')
# rec.RecoLepEnNue     | float                    | AsDtype('>f4')
# rec.RecoLepEnNumu    | float                    | AsDtype('>f4')
# rec.RecoMethodNue    | int32_t                  | AsDtype('>i4')
# rec.RecoMethodNumu   | int32_t                  | AsDtype('>i4')
# rec.RegCNNNueE       | float                    | AsDtype('>f4')
# rec.SpecialHCRunId   | int32_t                  | AsDtype('>i4')
# rec.SpecialRunWeight | double                   | AsDtype('>f8')
# rec.TrackMomMetho... | int32_t                  | AsDtype('>i4')
# rec.VisTrue_NDFD     | double                   | AsDtype('>f8')
# rec.W                | float                    | AsDtype('>f4')
# rec.X                | float                    | AsDtype('>f4')
# rec.Y                | float                    | AsDtype('>f4')
# rec.abspos_x         | double                   | AsDtype('>f8')
# rec.cvnnc            | float                    | AsDtype('>f4')
# rec.cvnnue           | float                    | AsDtype('>f4')
# rec.cvnnumu          | float                    | AsDtype('>f4')
# rec.cvnnutau         | float                    | AsDtype('>f4')
# rec.cvwgt..length    | int32_t                  | AsDtype('>i4')
# rec.cvwgt            | float[]                  | AsJagged(AsDtype('>f4'))
# rec.det_x            | float                    | AsDtype('>f4')
# rec.eDepN            | float                    | AsDtype('>f4')
# rec.eDepOther        | float                    | AsDtype('>f4')
# rec.eDepP            | float                    | AsDtype('>f4')
# rec.eDepPi0          | float                    | AsDtype('>f4')
# rec.eDepPim          | float                    | AsDtype('>f4')
# rec.eDepPip          | float                    | AsDtype('>f4')
# rec.eN               | float                    | AsDtype('>f4')
# rec.eOther           | float                    | AsDtype('>f4')
# rec.eP               | float                    | AsDtype('>f4')
# rec.ePi0             | float                    | AsDtype('>f4')
# rec.ePim             | float                    | AsDtype('>f4')
# rec.ePip             | float                    | AsDtype('>f4')
# rec.ePipm            | double                   | AsDtype('>f8')
# rec.eRecProxy        | double                   | AsDtype('>f8')
# rec.eRec_FromDep     | float                    | AsDtype('>f4')
# rec.eRecoN           | float                    | AsDtype('>f4')
# rec.eRecoOther       | float                    | AsDtype('>f4')
# rec.eRecoP           | float                    | AsDtype('>f4')
# rec.eRecoPi0         | float                    | AsDtype('>f4')
# rec.eRecoPim         | float                    | AsDtype('>f4')
# rec.eRecoPip         | float                    | AsDtype('>f4')
# rec.eTotalPi0        | double                   | AsDtype('>f8')
# rec.event            | int32_t                  | AsDtype('>i4')
# rec.isCC             | int32_t                  | AsDtype('>i4')
# rec.isFD             | int32_t                  | AsDtype('>i4')
# rec.isFHC            | int32_t                  | AsDtype('>i4')
# rec.meta_run         | int32_t                  | AsDtype('>i4')
# rec.meta_subrun      | int32_t                  | AsDtype('>i4')
# rec.mode             | int32_t                  | AsDtype('>i4')
# rec.muon_contained   | int32_t                  | AsDtype('>i4')
# rec.muon_ecal        | int32_t                  | AsDtype('>i4')
# rec.muon_exit        | int32_t                  | AsDtype('>i4')
# rec.muon_tracker     | int32_t                  | AsDtype('>i4')
# rec.mvanue           | float                    | AsDtype('>f4')
# rec.mvanumu          | float                    | AsDtype('>f4')
# rec.mvaresult        | float                    | AsDtype('>f4')
# rec.nN               | int32_t                  | AsDtype('>i4')
# rec.nNucleus         | int32_t                  | AsDtype('>i4')
# rec.nP               | int32_t                  | AsDtype('>i4')
# rec.nUNKNOWN         | int32_t                  | AsDtype('>i4')
# rec.nd.LArID         | uint64_t                 | AsDtype('>u8')
# rec.nd.Residual      | float                    | AsDtype('>f4')
# rec.nd.TMSID         | uint64_t                 | AsDtype('>u8')
# rec.nd.cosTheta      | float                    | AsDtype('>f4')
# rec.nd.gar.gastpc... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.gastpc... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.nFSP      | int32_t                  | AsDtype('>i4')
# rec.nd.gar.partEv... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.partEv... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.pdg..l... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.pdg       | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.gar.ptrue.... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.ptrue     | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.trkLen... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.trkLen    | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.gar.trkLen... | int32_t                  | AsDtype('>i4')
# rec.nd.gar.trkLen... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.nshowers  | uint64_t                 | AsDtype('>u8')
# rec.nd.lar.ntracks   | uint64_t                 | AsDtype('>u8')
# rec.nd.lar.shower... | int32_t                  | AsDtype('>i4')
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.shower... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.lar.tracks... | int32_t                  | AsDtype('>i4')
# rec.nd.lar.tracks.E  | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.lar.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.ntrkmatch     | uint64_t                 | AsDtype('>u8')
# rec.nd.tms.ntracks   | uint64_t                 | AsDtype('>u8')
# rec.nd.tms.tracks... | int32_t                  | AsDtype('>i4')
# rec.nd.tms.tracks.E  | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.tms.tracks... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.trkmatch..... | int32_t                  | AsDtype('>i4')
# rec.nd.trkmatch.a... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.nd.trkmatch.l... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.trkmatch.t... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.nd.trkmatch.t... | float[]                  | AsJagged(AsDtype('>f4'))
# rec.niem             | int32_t                  | AsDtype('>i4')
# rec.nik0             | int32_t                  | AsDtype('>i4')
# rec.nikm             | int32_t                  | AsDtype('>i4')
# rec.nikp             | int32_t                  | AsDtype('>i4')
# rec.niother          | int32_t                  | AsDtype('>i4')
# rec.nipi0            | int32_t                  | AsDtype('>i4')
# rec.nipim            | int32_t                  | AsDtype('>i4')
# rec.nipip            | int32_t                  | AsDtype('>i4')
# rec.nuPDG            | int32_t                  | AsDtype('>i4')
# rec.nuPDGunosc       | int32_t                  | AsDtype('>i4')
# rec.nue_pid          | float                    | AsDtype('>f4')
# rec.numu_pid         | float                    | AsDtype('>f4')
# rec.nwgt_CrazyFlux   | int32_t                  | AsDtype('>i4')
# rec.perPOTWeight     | double                   | AsDtype('>f8')
# rec.pileup_energy    | double                   | AsDtype('>f8')
# rec.pot              | double                   | AsDtype('>f8')
# rec.reco_lepton_pdg  | int32_t                  | AsDtype('>i4')
# rec.reco_nc          | int32_t                  | AsDtype('>i4')
# rec.reco_nue         | int32_t                  | AsDtype('>i4')
# rec.reco_numu        | int32_t                  | AsDtype('>i4')
# rec.reco_q           | int32_t                  | AsDtype('>i4')
# rec.run              | int32_t                  | AsDtype('>i4')
# rec.sigma_Elep_reco  | float                    | AsDtype('>f4')
# rec.sigma_Ev_reco    | float                    | AsDtype('>f4')
# rec.sigma_nue_pid    | float                    | AsDtype('>f4')
# rec.sigma_numu_pid   | float                    | AsDtype('>f4')
# rec.subrun           | int32_t                  | AsDtype('>i4')
# rec.theta_reco       | float                    | AsDtype('>f4')
# rec.total_xsSyst_... | float                    | AsDtype('>f4')
# rec.vtx_x            | float                    | AsDtype('>f4')
# rec.vtx_y            | float                    | AsDtype('>f4')
# rec.vtx_z            | float                    | AsDtype('>f4')
# rec.wgt_CrazyFlux... | int32_t                  | AsDtype('>i4')
# rec.wgt_CrazyFlux    | float[]                  | AsJagged(AsDtype('>f4'))
# rec.xsSyst_wgt..l... | int32_t                  | AsDtype('>i4')
# rec.xsSyst_wgt.el... | int32_t[]                | AsJagged(AsDtype('>i4'))
# rec.xsSyst_wgt.el... | int32_t                  | AsDtype('>i4')
# rec.xsSyst_wgt.elems | float[]                  | AsJagged(AsDtype('>f4'))
# rec.xsSyst_wgt.el... | int32_t[]                | AsJagged(AsDtype('>i4'))

# %%
pl.Config.set_tbl_rows(20)
@dataclass
class Flavour:
    pdg:int
    name:str
    name_latex:str
    cvn:str

flavours = {
    -16: Flavour(-16, "nutaubar", r"$\overline{\nu}_\tau$", "rec.cvnnutau"),
    -14: Flavour(-14, "numubar", r"$\overline{\nu}_\mu$", "rec.cvnnumu"),
    -12 : Flavour(-12, "nuebar", r"$\overline{\nu}_e$", "rec.cvnnue"),
    12: Flavour(12, "nue", r"$\nu_e$", "rec.cvnnue"),
    14: Flavour(14, "numu", r"$\nu_\mu$", "rec.cvnnumu"),
    16: Flavour(16, "nutau", r"$\nu_\tau$", "rec.cvnnutau")
}

def get_max():
    return  pl.max('rec.cvnnue','rec.cvnnumu','rec.cvnnutau','rec.cvnnc')

def define_flavour(df:pl.DataFrame):
    df = df.with_columns(
        Flavour = pl.when(get_max()==None).then(0).otherwise(
        pl.when((pl.col('rec.cvnnue') >= 0.5)).then(12).otherwise(
        pl.when(pl.col('rec.cvnnumu')>=0.5).then(14).otherwise(
        pl.when(pl.col('rec.cvnnc')>=0.5).then(0).otherwise(16)
        )))
    )
    return df

def fill_empty_categories(df, labels):

    empty_result = pl.DataFrame({ col: [0. for _ in labels] for col in df.columns })
    empty_result.with_columns(pl.Series(name='Ecut', values=labels))

    # works, but need to add manually.
    # empty_result = pl.DataFrame({'purity': 0., 'completeness': 0., 'total_events':0., 'Ecut': labels})
    empty_result = empty_result.with_columns(Ecut=pl.col('Ecut').cast(pl.Int16))

    out = pl.concat([empty_result,df],how='diagonal')
    out = out.groupby('Ecut').agg(
        pl.all().sum()
        # purity = pl.col("purity").sum(),
        # completeness = pl.col("completeness").sum(),
    ).sort('Ecut')
    return out

def eval_err(var:str):
    return pl.when(pl.col(var)!=0).then(1./pl.col(var).sqrt()).otherwise(1)

def eval_err_div(f:str, x:str, y:str, errx:str, erry:str):
    return pl.when(pl.col(x)!=0).then((pl.col(f)/pl.col(x)).pow(2)*((pl.col(y)*pl.col(errx)).pow(2) + (pl.col(x)*pl.col(erry)).pow(2)).sqrt()).otherwise(
        pl.when(pl.col(y)>1).then((1./(pl.col(x) + pl.col(y))).pow(2)*((pl.col(y)*pl.col(errx)).pow(2) + (pl.col(x)*pl.col(erry)).pow(2)).sqrt()).otherwise(0.)
    )

# %%
len_cm = [9.833E-1, 1.786E0, 3.321E0, 6.598E0, 1.058E1,
          3.084E1, 4.250E1, 6.732E1, 1.063E2, 1.725E2,
          2.385E2, 4.934E2, 6.163E2, 8.552E2, 1.202E3,
          1.758E3, 2.297E3, 4.359E3, 5.354E3, 7.298E3, 1.013E4, 1.469E4, 1.910E4, 3.558E4, 4.326E4, 5.768E4, 7.734E4, 1.060E5, 1.307E5]
 
KE_MeV = [10, 14, 20, 30, 40, 80, 100, 140, 200, 300, 400, 800, 1000, 1400, 2000, 3000,
          4000, 8000, 10000, 14000, 20000, 30000, 40000, 80000, 100000, 140000,
          200000, 300000, 400000]
from scipy.interpolate import CubicSpline
spl = CubicSpline(len_cm,KE_MeV)

def flavour(pdg):
    return pl.col('rec.nuPDG') == pdg
    # return pl.col('Flavour') == pdg

def energy(pdg):
    En = 'Ev'
    # return (pl.col(En) >=1 ) & (pl.col(En) <= 10)
    return (pl.col(En) >=0 )
def checkEnergy(df):
    E = df.with_columns(
        lep_range_cm = (pl.col('rec.RecoLepEnNumu').pow(2) - 0.105*0.105).sqrt()

    ).with_columns(
        Ev = pl.col('rec.Ev'),
        Ev_reco = pl.col('rec.Ev_reco'),
        Ev_reco_nue = pl.col('rec.Ev_reco_nue'),
        Ev_reco_numu = pl.col('rec.Ev_reco_numu'),
        Ev_reco_numu_h = ((pl.col('lep_range_cm').apply(lambda x: spl(x)/1000).pow(2) + 0.105*0.105)).sqrt()+pl.col('rec.RecoHadEnNumu'),
        LepE_h = ((pl.col('lep_range_cm').apply(lambda x: spl(x)/1000).pow(2) + 0.105*0.105)).sqrt()
    ).with_columns(
        Eres = pl.col("Ev_reco")/pl.col("Ev") - 1,
        Eres_nue = pl.col("Ev_reco_nue")/pl.col("Ev") - 1,
        Eres_numu = pl.col("Ev_reco_numu")/pl.col("Ev") - 1,
        Eres_numu_h = pl.col("Ev_reco_numu_h")/pl.col("Ev") - 1,
    )
    return E
E = checkEnergy(df)
Eold = checkEnergy(dfold)
fig, axs = plt.subplots(1,2,figsize=(14,4))
binsmu = 400
binsmu_z = 200
binse = 200

limmu = 400
limmu_z = 20
lime = 1
ax = axs[0]
ax.hist(E.filter(flavour(14)).filter(pl.col('rec.isCC')==1).filter(energy(14))['Eres_numu'], bins=binsmu, range=(-1,limmu), log=True, histtype='step', label='HD AV 2.5 random');
# ax.hist(Eold.filter(flavour(14)).filter(pl.col('rec.isCC')==1).filter(energy(14))['Eres_numu'], bins=400, range=(-1,limmu), log=True, histtype='step', label='HD AV');
ax.set_title(r'Resolution $\nu_\mu$ reco energy')
ax.set_xlabel(r'$\frac{E_{Reco}}{E_{True}} - 1$')
ax.legend()
ax = axs[1]
ax.hist(E.filter(flavour(14)).filter(pl.col('rec.isCC')==1).filter(energy(14))['Eres_numu'], bins=binsmu_z, range=(-1,limmu_z), log=True, histtype='step', label='HD AV 2.5 random');
# ax.hist(Eold.filter(flavour(14)).filter(pl.col('rec.isCC')==1).filter(energy(14))['Eres_numu'], bins=200, range=(-1,limmu_z), log=True, histtype='step', label='HD AV');
ax.set_title(r'Resolution $\nu_\mu$ reco energy (zoom)')
ax.set_xlabel(r'$\frac{E_{Reco}}{E_{True}} - 1$')
ax.legend()
plt.figure(figsize=(14,4))
plt.hist(E.filter(flavour(12)).filter(pl.col('rec.isCC')==1).filter(energy(12))['Eres_nue'], bins=binse, range=(-1, lime),log=True, histtype='step', label='HD AV 2.5 random');
# plt.hist(Eold.filter(flavour(12)).filter(pl.col('rec.isCC')==1).filter(energy(12))['Eres_nue'], bins=200, range=(-1, lime),log=True, histtype='step', label='HD AV');
plt.title(r'Resolution $\nu_e$ reco energy')
plt.xlabel(r'$\frac{E_{Reco}}{E_{True}} - 1$')
plt.legend()

# %%
fig, axs = plt.subplots(1,1,figsize=(14,4))
binsmu_z = 200
binse = 200

limmu_z = 1
lime = 1
ax = axs
ax.hist(E.filter(flavour(14)).filter(pl.col('rec.isCC')==1).filter(energy(14))['Eres_numu_h'], bins=binsmu_z, range=(-1,limmu_z), log=True, histtype='step', label='HD AV 2.5 random');
# ax.hist(Eold.filter(flavour(14)).filter(pl.col('rec.isCC')==1).filter(energy(14))['Eres_numu'], bins=200, range=(-1,limmu_z), log=True, histtype='step', label='HD AV');
ax.set_title(r'Resolution $\nu_\mu$ reco energy (zoom)')
ax.set_xlabel(r'$\frac{E_{Reco}}{E_{True}} - 1$')
ax.legend()
plt.figure(figsize=(14,4))
plt.hist(E.filter(flavour(12)).filter(pl.col('rec.isCC')==1).filter(energy(12))['Eres_nue'], bins=binse, range=(-1, lime),log=True, histtype='step', label='HD AV 2.5 random');
# plt.hist(Eold.filter(flavour(12)).filter(pl.col('rec.isCC')==1).filter(energy(12))['Eres_nue'], bins=200, range=(-1, lime),log=True, histtype='step', label='HD AV');
plt.title(r'Resolution $\nu_e$ reco energy')
plt.xlabel(r'$\frac{E_{Reco}}{E_{True}} - 1$')
plt.legend()

# %%
E = checkEnergy(df)
Eold = checkEnergy(dfold)
Emu = E.filter(flavour(14)).filter(pl.col('rec.isCC')==1).filter(energy(14))
Ee = E.filter(flavour(12)).filter(pl.col('rec.isCC')==1).filter(energy(12))
ax:plt.Axes
binsx = np.logspace(-1,np.log10(100),100)
binsy = np.logspace(-1,np.log10(1e5),100)
# binsx = np.linspace(0.1,20,200)
# binsy = np.linspace(0.1,20,200)
fig, ax = plt.subplots(1,2,figsize=(14,8))
ax[0].hist2d(Emu['Ev'], Emu['Ev_reco_numu'], bins=(binsx,binsy), range=((0,10),(0,10)), norm = LogNorm())
ax[0].set_xlabel(rf'True {flavours[14].name_latex} Energy (GeV)')
ax[0].set_ylabel(rf'Reco {flavours[14].name_latex} Energy (GeV)')
ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[1].hist2d(Ee['Ev'], Ee['Ev_reco_nue'], bins=(200,200), range=((0,10),(0,10)), norm = LogNorm());
ax[1].set_xlabel(rf'True {flavours[12].name_latex} Energy (GeV)')
ax[1].set_ylabel(rf'Reco {flavours[12].name_latex} Energy (GeV)')
plt.show()

# %%
E = checkEnergy(df)
Eold = checkEnergy(dfold)
Emu = E.filter(flavour(14)).filter(pl.col('rec.isCC')==1).filter(energy(14)).filter(pl.col('rec.LongestTrackContNumu') != -1)
Ee = E.filter(flavour(12)).filter(pl.col('rec.isCC')==1).filter(energy(12))
ax:plt.Axes
binsx = np.logspace(-1,np.log10(100),100)
binsy = np.logspace(-1,np.log10(100),100)
# binsx = np.linspace(-1,20,200)
# binsy = np.linspace(-1,20,200)
fig, ax = plt.subplots(1,2,figsize=(14,8))
ax[0].hist2d(Emu['Ev'], Emu['Ev_reco_numu_h'], bins=(binsx,binsy), range=((0,10),(0,10)), norm = LogNorm())
ax[0].set_xlabel(rf'True {flavours[14].name_latex} Energy (GeV)')
ax[0].set_ylabel(rf'Reco {flavours[14].name_latex} Energy (GeV)')
ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[1].hist2d(Ee['Ev'], Ee['Ev_reco_nue'], bins=(200,200), range=((0,10),(0,10)), norm = LogNorm());
ax[1].set_xlabel(rf'True {flavours[12].name_latex} Energy (GeV)')
ax[1].set_ylabel(rf'Reco {flavours[12].name_latex} Energy (GeV)')
plt.show()

# %%
def make_plot(ax:plt.Axes, val:str, df:pl.DataFrame):
    df = df.filter(pl.col('rec.isCC') != 1)
    ax.hist(df[val])
    ax.set_xlabel(val)
    ax.set_ylabel('# of events')
fig, axs = plt.subplots(1,1,figsize=(14,6))
make_plot(axs, 'rec.LongestTrackContNumu', df)
# make_plot(axs[1], 'rec.TrackMomMethodNumu', df)

# df.select(
#     pl.col('rec.')
# )

# %%
# plt.plot(df.filter(pl.col('rec.nuPDG')==14).filter(pl.col('rec.isCC')==1)['rec.RecoHadEnNumu'])
binsx = np.logspace(-1,1,200)
plt.hist2d(Emu['rec.LepE'],Emu['LepE_h'], bins=(binsx,binsx), range=((0,10),(0,10)), norm=LogNorm());
plt.xscale('log')
plt.yscale('log')
